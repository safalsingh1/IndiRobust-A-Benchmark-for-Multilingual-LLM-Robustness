# %% [markdown]
# # Robustness Analysis Notebook
#
# This notebook visualizes the results of the multilingual robustness benchmark.

# %%
# %matplotlib inline
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.visualize_results import load_results, plot_robustness_per_language, plot_perturbation_comparison, plot_cross_lingual_gap

# Load Data
results_dir = "../results"
df = load_results(results_dir)
print(df.head())

# %%
output_dir = "../results/figures"
os.makedirs(output_dir, exist_ok=True)

if not df.empty:
    plot_robustness_per_language(df, output_dir)
    plot_perturbation_comparison(df, output_dir)
    plot_cross_lingual_gap(df, output_dir)
else:
    print("No results found. Please run experiments first.")
